# %% [markdown]
# <a href="https://colab.research.google.com/github/chess-drive/AIFFEL_quest_eng/blob/main/Python/Py04/20260115_kiosk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
Created on 2026. 1. 15.

@author: chaliepark
'''
# 문제 3-3. 클래스 업데이트
# 앞에서 구현했던 메서드들을 Kiosk 클래스에 추가합니다. 직접 코드를 작성해 보세요!

# 문제 2-3. 주문 메서드

# 음료의 온도에 따라 temp 변수를 "HOT" 또는 "ICE"로 지정하세요.

class Kiosk:
    menu_temp=[]
    price_temp=[]
    def __init__(self):
        # 문제 2-1의 답을 입력하세요.
        self.menu =['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']
        self.price =[2000, 3000, 3000, 2500, 2500, 3000]

    # 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):
            print(i + 1, self.menu[i], ' : ', self.price[i], '원')

    # 주문 메서드
    def menu_select(self):
        print()  # 줄 바꿈
        order_bool=True
        while order_bool:
            n = 0
            while n < 1 or len(self.menu) < n:
                n = int(input("음료 번호를 입력하세요 : "))  # 음료 번호 입력

                # 메뉴판에 있는 음료 번호일때
                if 1 <= n & n <= len(self.menu):
                    self.price_sum = self.price[n-1]  # 선택 음료의 가격

                # 메뉴판에 없는 번호일 때
                else:
                    print("없는 메뉴입니다. 다시 주문해 주세요.")

            # 음료 온도 물어보기
            t = 0  # 기본값을 넣어주고
            while t != 1 and t != 2:  # 1이나 2를 입력할 때까지 물어보기
                t= int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
                # 문제 2-3. 음료의 온도에 따라 temp 변수를 "HOT" 또는 "ICE"로 지정하세요.
                # 힌트: if문을 활용해보세요.
                if t == 1:
                    self.temp = "HOT"
                elif t == 2:
                    self.temp = "ICE"
                else:
                    print("1과 2 중 하나를 입력하세요.\n")
            # 문제 2-2의 답을 입력하세요.
            self.menu_temp.append(self.temp+" "+self.menu[n-1])
            self.price_temp.append(self.price[n-1])
            order_bool=True if input("계속 주문 하시겠습니까?(y/n)") == "y" else False

    def pay(self):
        print("계산될금액: ",sum(self.price_temp),"원")
        pay_sel =0
        while pay_sel != 1 and pay_sel != 2:
            pay_sel = int(input("결제할 방법을 선택해주세요.(1:현금,2:카드)"))
            if pay_sel == 1:
                self.pay_mthd = "현금"
                print("직원을 호출하겠습니다.")
            elif pay_sel == 2:
                self.pay_mthd = "카드"
                print("IC칩 방향에 맞게 카드를 꽂아주세요.")

    def table(self):
        print('⟝' + '-' * 30 + '⟞')
        for i in range(5):
            print('|' + ' ' * 31 + '|')

        for i in range(len(self.menu_temp)):
            print(self.menu_temp[i], ' : ', self.price_temp[i])

        print('합계 금액 :', sum(self.price_temp))

        for i in range(5):
            print('|' + ' ' * 31+ '|')
        print('⟝' + '-' * 30 + '⟞')

b = Kiosk()  # 객체 생성
b.menu_print()  # 메뉴 출력
b.menu_select()  # 주문
b.pay()  # 지불
b.table()  # 주문표 출력
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
#
# 음료 번호를 입력하세요 : 3
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# 계속 주문 하시겠습니까?(y/n)y
# 음료 번호를 입력하세요 : 3
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# 계속 주문 하시겠습니까?(y/n)y
# 음료 번호를 입력하세요 : 3
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# 계속 주문 하시겠습니까?(y/n)n
# 계산될금액:  9000 원
# 결제할 방법을 선택해주세요.(1:현금,2:카드)2
# IC칩 방향에 맞게 카드를 꽂아주세요.
# ⟝------------------------------⟞
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ICE mocha  :  3000
# ICE mocha  :  3000
# ICE mocha  :  3000
# 합계 금액 : 9000
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ⟝------------------------------⟞
