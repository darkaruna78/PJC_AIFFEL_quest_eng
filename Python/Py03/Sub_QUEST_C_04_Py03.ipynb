# %% [markdown]
# <a href="https://colab.research.google.com/github/chess-drive/AIFFEL_quest_eng/blob/main/Python/Py03/Sub_QUEST_C_04_Py03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math as m

def plus(a,b):
    return a+b

def minus(a,b):
    return a-b
def multiply(a,b):
    return a*b
def divide(a,b):
    return a/b


def best_calc():
    while True:
        try:
            rtn_num=0
            num1=int(input('num1 입력해주세요:'))
            yeon=input('연산자를 입력해주세요(+,-,*,/,**):')
            num2=int(input('num2 입력해주세요:'))

            if yeon == '+':
                rtn_num=plus(num1,num2)
            elif yeon == '-':
                rtn_num=minus(num1,num2)
            elif yeon == '*':
                rtn_num=multiply(num1,num2)
            elif yeon == '/':
                rtn_num=divide(num1,num2)
            elif yeon == '**':
                rtn_num=pow(num1,num2)
            else:
                print('지원하지 않는연산자입니다.')
                continue

        except ValueError:
            print('정수가 아닙니다.')
        except ZeroDivisionError:
            print('0으로 나눌 수 없습니다.')
        finally:
            print(rtn_num)



best_calc()
# Out:
# num1 입력해주세요:1
# 연산자를 입력해주세요(+,-,*,/,**):+
# num2 입력해주세요:1
# 2
# num1 입력해주세요:1
# 연산자를 입력해주세요(+,-,*,/,**):^
# num2 입력해주세요:1
# 지원하지 않는연산자입니다.
# 0
# num1 입력해주세요:+
# 정수가 아닙니다.
# 0
# num1 입력해주세요:1
# 연산자를 입력해주세요(+,-,*,/,**):/
# num2 입력해주세요:0
# 0으로 나눌 수 없습니다.
# 0
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4281008562.py in <cell line: 0>()
#      43
#      44
# ---> 45 best_calc()
#
# /tmp/ipython-input-4281008562.py in best_calc()
#      16         try:
#      17             rtn_num=0
# ---> 18             num1=int(input('num1 입력해주세요:'))
#      19             yeon=input('연산자를 입력해주세요(+,-,*,/,**):')
#      20             num2=int(input('num2 입력해주세요:'))
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
